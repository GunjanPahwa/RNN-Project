# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent=['the glass of milk',
      'the glass of juice',
      'the cup of tea',
      'I am a good boy',
      'I am a good developer',
      'understand the meaning of words',
      'your videos are good']

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
#Define the vocabulary size
voc_size=10000

# %%
#One Hot representation
one_hot_repr=[one_hot(words,voc_size) for words in sent]
one_hot_repr
# Out:
# [[8433, 1111, 954, 6636],
#  [8433, 1111, 954, 3153],
#  [8433, 1437, 954, 6355],
#  [1774, 7719, 786, 6420, 2570],
#  [1774, 7719, 786, 6420, 5818],
#  [7402, 8433, 5451, 954, 7236],
#  [2329, 6625, 9435, 6420]]

# %%
#word embedding representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np
#we need to make all sentences of equal size or we would not be able to train it in RNN.
#all the words going in RNN would be going for a fixed number of timestamp and based on sentence size
#so using pad_sequences we try to set a maximum sentence length

# %%
sent_length=8 #for shorter sentences it will add the remaining number of 0's before or after
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length) #pre means that 0's will be added at the beginning of the sentence

# %%
print(embedded_docs)
# Out:
# [[   0    0    0    0 8433 1111  954 6636]
#  [   0    0    0    0 8433 1111  954 3153]
#  [   0    0    0    0 8433 1437  954 6355]
#  [   0    0    0 1774 7719  786 6420 2570]
#  [   0    0    0 1774 7719  786 6420 5818]
#  [   0    0    0 7402 8433 5451  954 7236]
#  [   0    0    0    0 2329 6625 9435 6420]]

# %%
#feature representation
dim=10 #dimensions

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# c:\Users\HP\anaconda3\envs\RNN\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs) #every word represented in 10 dimensions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# array([[[ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [-0.01424663,  0.04666208,  0.02873259, -0.03101235,
#           0.00652445,  0.03379171,  0.01943352, -0.01731427,
#           0.03090117,  0.00306433],
#         [ 0.00139553,  0.0324671 , -0.02090414,  0.02538896,
#          -0.00372642,  0.01466418,  0.03894671, -0.01240788,
#          -0.01768075, -0.01916767],
#         [-0.02943122, -0.01284153,  0.0111632 , -0.00052077,
#          -0.01478312, -0.04790782,  0.04788709, -0.03593699,
#           0.00510775,  0.01350487],
#         [-0.00489917,  0.01692248,  0.00523005,  0.0087993 ,
#          -0.03375401,  0.03322733,  0.02248475, -0.04693146,
#          -0.03685294, -0.02084254]],
#
#        [[ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [-0.01424663,  0.04666208,  0.02873259, -0.03101235,
#           0.00652445,  0.03379171,  0.01943352, -0.01731427,
#           0.03090117,  0.00306433],
#         [ 0.00139553,  0.0324671 , -0.02090414,  0.02538896,
#          -0.00372642,  0.01466418,  0.03894671, -0.01240788,
#          -0.01768075, -0.01916767],
#         [-0.02943122, -0.01284153,  0.0111632 , -0.00052077,
#          -0.01478312, -0.04790782,  0.04788709, -0.03593699,
#           0.00510775,  0.01350487],
#         [-0.00089826, -0.03298408,  0.0024757 ,  0.01404835,
#           0.01439034,  0.04976109, -0.00893031,  0.02410282,
#           0.04485356,  0.00436282]],
#
#        [[ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [-0.01424663,  0.04666208,  0.02873259, -0.03101235,
#           0.00652445,  0.03379171,  0.01943352, -0.01731427,
#           0.03090117,  0.00306433],
#         [ 0.04258405,  0.03474302,  0.01510963, -0.02000885,
#          -0.01391194,  0.02452557, -0.00307763,  0.01365117,
#          -0.04631364, -0.02406861],
#         [-0.02943122, -0.01284153,  0.0111632 , -0.00052077,
#          -0.01478312, -0.04790782,  0.04788709, -0.03593699,
#           0.00510775,  0.01350487],
#         [-0.03577384, -0.03104985, -0.04036779, -0.02708088,
#           0.01192801, -0.00820053,  0.02139768, -0.03835112,
#          -0.02644253, -0.00365735]],
#
#        [[ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [-0.02386963,  0.02405492, -0.04165319,  0.02891574,
#          -0.04267794,  0.01308376,  0.00409653,  0.02866998,
#           0.03607092,  0.02702134],
#         [-0.02270639,  0.00777323,  0.03261361, -0.01320633,
#           0.00310389, -0.00908389, -0.03953161, -0.02435336,
#          -0.04252918, -0.04693571],
#         [ 0.04960488, -0.02852303,  0.04051686,  0.03213983,
#           0.0496478 , -0.02685389, -0.00463526,  0.02389529,
#           0.03084384,  0.01056681],
#         [-0.04681064, -0.03271012, -0.04216269, -0.04225677,
#           0.01726088, -0.03222767,  0.04611227,  0.00955522,
#          -0.01949926,  0.01938787],
#         [ 0.01501192, -0.0456877 ,  0.04388462, -0.00288056,
#          -0.04899653,  0.03521231, -0.03617871,  0.00474402,
#          -0.02351486, -0.0427636 ]],
#
#        [[ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [-0.02386963,  0.02405492, -0.04165319,  0.02891574,
#          -0.04267794,  0.01308376,  0.00409653,  0.02866998,
#           0.03607092,  0.02702134],
#         [-0.02270639,  0.00777323,  0.03261361, -0.01320633,
#           0.00310389, -0.00908389, -0.03953161, -0.02435336,
#          -0.04252918, -0.04693571],
#         [ 0.04960488, -0.02852303,  0.04051686,  0.03213983,
#           0.0496478 , -0.02685389, -0.00463526,  0.02389529,
#           0.03084384,  0.01056681],
#         [-0.04681064, -0.03271012, -0.04216269, -0.04225677,
#           0.01726088, -0.03222767,  0.04611227,  0.00955522,
#          -0.01949926,  0.01938787],
#         [-0.0464046 , -0.04013366,  0.00566231,  0.04063774,
#          -0.03765224,  0.03356046, -0.04147315, -0.02072277,
#          -0.02010295,  0.01932298]],
#
#        [[ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [-0.03898212, -0.00746746,  0.04230868,  0.00541101,
#           0.04756821,  0.04300319,  0.03095816, -0.03352995,
#           0.00221317,  0.03445009],
#         [-0.01424663,  0.04666208,  0.02873259, -0.03101235,
#           0.00652445,  0.03379171,  0.01943352, -0.01731427,
#           0.03090117,  0.00306433],
#         [ 0.01941064,  0.02006369, -0.01442228, -0.02104678,
#          -0.00696079,  0.00046999,  0.04096167,  0.00336367,
#          -0.04794209, -0.00431765],
#         [-0.02943122, -0.01284153,  0.0111632 , -0.00052077,
#          -0.01478312, -0.04790782,  0.04788709, -0.03593699,
#           0.00510775,  0.01350487],
#         [ 0.02923666, -0.03085964,  0.02130607, -0.01958689,
#           0.04731445,  0.00031378,  0.00633789,  0.03607469,
#          -0.00031744, -0.00555379]],
#
#        [[ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [ 0.0028423 ,  0.04546655,  0.02169183,  0.03107656,
#          -0.04478921,  0.04552071,  0.00804485, -0.00147621,
#          -0.04398173, -0.02940161],
#         [-0.04684982,  0.00464605, -0.00128162, -0.00690327,
#           0.03537918, -0.03502043, -0.04986029,  0.02294249,
#           0.02263314,  0.00124265],
#         [ 0.00081081, -0.00265612, -0.00067317,  0.03766182,
#           0.0316    ,  0.04610041, -0.04502958,  0.00694457,
#           0.02726622, -0.01634385],
#         [-0.02873436, -0.02252424, -0.01855508,  0.00670253,
#          -0.03688983,  0.00410638, -0.03152495, -0.03509389,
#           0.00195676, -0.04182976],
#         [-0.04681064, -0.03271012, -0.04216269, -0.04225677,
#           0.01726088, -0.03222767,  0.04611227,  0.00955522,
#          -0.01949926,  0.01938787]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 8433, 1111,  954, 6636], dtype=int32)
